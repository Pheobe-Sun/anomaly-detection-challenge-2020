# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob

# %% [markdown]
# # Training dataset

# %%
work_dir = os.getcwd()
data_dir ="../../for_students/data_v2"
train_dir = os.path.join(data_dir, 'training')
train_str = os.path.join(train_dir, 'training_{}.csv')
train_df_1 = pd.read_csv(train_str.format('1'))
train_df_2  = pd.read_csv(train_str.format('2'))
train_df_3  = pd.read_csv(train_str.format('3'))
train_df_4  = pd.read_csv(train_str.format('4'))
train_df_5  = pd.read_csv(train_str.format('5'))
train_df_100  = pd.read_csv(train_str.format('100'))
# drop 'request_count' column in dataset_100
train_df_100 = train_df_100.drop("request_count", axis=1)
train_dfs = [train_df_1,train_df_2,train_df_3,train_df_4,train_df_5,train_df_100]

# %%
# train_df_100

# %%
for df in train_dfs:
    plt.figure()
    df['kpi_value'].plot()
    df["anomaly_label"][df["anomaly_label"]==1].plot(style="o")

# %% [markdown]
# # Test dataset

# %%
# get all file names in the test data folder
os.chdir("../../for_students/data_v2")
# os.getcwd()
extension = 'csv'
filenames = [filename for filename in glob.glob('*.{}'.format(extension))]
filenames
# Out:
# ['dataset_1.csv',
#  'dataset_10.csv',
#  'dataset_100.csv',
#  'dataset_101.csv',
#  'dataset_102.csv',
#  'dataset_103.csv',
#  'dataset_105.csv',
#  'dataset_106.csv',
#  'dataset_11.csv',
#  'dataset_12.csv',
#  'dataset_13.csv',
#  'dataset_2.csv',
#  'dataset_3.csv',
#  'dataset_4.csv',
#  'dataset_5.csv',
#  'dataset_6.csv',
#  'dataset_7.csv',
#  'dataset_8.csv',
#  'dataset_9.csv']

# %%
# Change back to your working directory
os.chdir(work_dir)
# print(work_dir)
# a = os.path.join(work_dir, 'images')
# print(a)
# Out:
# C:\Users\Pheobe\Documents\[B]Huawei-Challenge-2020\anomaly-detection-challenge-2020\notebooks
# C:\Users\Pheobe\Documents\[B]Huawei-Challenge-2020\anomaly-detection-challenge-2020\notebooks\images

# %%
for filename in filenames:
    test_df = pd.read_csv(filename)
    fig = plt.figure()
    test_df['kpi_value'].plot()
    fig.savefig(os.path.join(work_dir, 'images', 'test_{}'.format(filename.strip(".csv"))))
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-0563623939d6> in <module>
#       3     fig = plt.figure()
#       4     test_df['kpi_value'].plot()
# ----> 5     fig.savefig(os.path.join('images', 'test_{}'.format(filename.strip(".csv"))))
#       6     plt.show()
#
# c:\users\pheobe\miniconda3\envs\deep-learning\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# c:\users\pheobe\miniconda3\envs\deep-learning\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2103                     orientation=orientation,
# ...
